# %% [markdown]
# #### Exercicio
#
# 1 - Abra o arquivo aula_10_dataset_exercicio.csv
#
# 2 - Identifique os outliers da coluna Salario_RS usando:
# - regra de negocio (salario nao pode ser negativo)
# - metodo estatistico IQR
#
# 3 - Crie uma coluna chamada Flag_Outlier com True/False
#
# 4 - Compare media, mediana e desvio padrao da coluna Salario_RS:
# - antes do tratamento
# - depois de remover valores invalidos e extremos
#
# 5 - Monte um dataframe final tratado e exiba as 10 primeiras linhas

# %%
# Responda aqui
