# %% [markdown]
# # Exercício
#
# Abra o arquivo 'aula_08_dataset_exercicio.csv'.
#
# 1. Converta a coluna 'Data_Checkin' para o formato datetime.
# 2. Garanta que valores inválidos não quebrem o código (use errors='coerce').
# 3. Crie uma nova coluna apenas com o DIA do check-in.
# 4. Exiba as primeiras linhas do dataframe resultante.

# %%
# Responda aqui
