# %% [markdown]
# I - Abra o arquivo aula_05_exercicio_dataset.csv
# II - Substitua os valores das colunas Disponível e Categoria para que contenham apnenas strings. Abaixo segue a tabela
# de equivalência entre o número e o nome da categoria.
# Categorias:
# 1 - Eletrônicos
# 2 - Armazenamento
# 3 - Periféricos
# 4 - Acessórios

# %%
# Responda aqui
