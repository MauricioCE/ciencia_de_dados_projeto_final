# %% [markdown]
# #### Exercicio
#
# 1 - Abra o arquivo aula_11_dataset_exercicio.csv
#
# 2 - Identifique as unidades presentes nas colunas Altura e Peso
#
# 3 - Padronize as unidades:
# - Altura para centimetros (nova coluna Altura_cm)
# - Peso para quilogramas (nova coluna Peso_kg)
#
# 4 - Compare as medias por Produto:
# - sem padronizar unidade
# - com unidade padronizada
#
# 5 - Gere um dataframe final contendo apenas Produto, Altura_cm e Peso_kg

# %%
# Responda aqui
