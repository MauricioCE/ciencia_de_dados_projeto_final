# %% [markdown]
# # Exercício de Fixação - Limpeza de Texto
#
# Abra o arquivo 'aula_09_dataset_exercicio.csv'.
#
# 1. Padronize a coluna 'Setor': remova espaços e deixe tudo em MAIÚSCULO.
# 2. Corrija a coluna 'Setor' para que existam apenas os nomes: 'ELETRONICOS' e 'MOVEIS' (remova acentos se necessário).
# 3. Padronize a coluna 'Status' para que fiquem todas em MAIÚSCULO.
# 4. Exiba a contagem de valores (value_counts) da coluna 'Setor' após a limpeza.

# %%
# Responda aqui
